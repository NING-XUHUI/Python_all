# %%
import matplotlib.image as imgplt
import matplotlib.pyplot as plt
from PIL import Image

# %%
img1 = imgplt.imread('./kaggle/datasets/实际效果/1/image.jpg')
img2 = imgplt.imread('./kaggle/datasets/实际效果/2/image.jpg')
img3 = imgplt.imread('./kaggle/datasets/实际效果/3/image.jpg')
img4 = imgplt.imread('./kaggle/datasets/实际效果/4/image.jpg')
img5 = imgplt.imread('./kaggle/datasets/实际效果/5/image.jpg')
img6 = imgplt.imread('./kaggle/datasets/实际效果/6/image.jpg')
img7 = imgplt.imread('./kaggle/datasets/实际效果/7/image.jpg')
img8 = imgplt.imread('./kaggle/datasets/实际效果/8/image.jpg')
img9 = imgplt.imread('./kaggle/datasets/实际效果/9/image.jpg')


op1 = imgplt.imread('./kaggle/datasets/实际效果/1/op.png')

# %%
plt.figure()
plt.suptitle('Demo1')
plt.subplot(1, 2, 1), plt.title('Input')
plt.imshow(img1), plt.axis('off')

plt.subplot(1, 2, 2), plt.title('Output')
plt.imshow(op1), plt.axis('off')
# Out:
# (<matplotlib.image.AxesImage at 0x7fcdea257d90>, (-0.5, 904.5, 31.5, -0.5))
