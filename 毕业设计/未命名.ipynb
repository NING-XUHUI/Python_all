# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Guassian.png      demo.py           houghTest5.png    wav.png
# TEST.bmp          example.py        nlm.png           未命名.ipynb
# TEST.jpg          houghTest1.png    noiseTest.bmp     倾斜校正 2.py
# TEST2.bmp         houghTest2.bmp    noiseTest.jpg     倾斜校正.py
# TEST2.jpg         houghTest2.png    noiseTest2.bmp    图像分割.py
# a.png             houghTest3.png    noiseTest3.bmp    文字分割.py
# all               houghTest4.bmp    noiseTest3.jpg
# bm3d.png          houghTest4.png    test.py

# %%
img = cv.imread("./TEST.jpg")

# %%
gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)

# %%
plt.subplot(1,2,1)
plt.imshow(cv.cvtColor(img, cv.COLOR_RGB2BGR))
plt.xticks([])
plt.yticks([])
plt.title("原图")
plt.subplot(1,2,2)
plt.imshow(gray, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title("灰度化")
# Out:
# Text(0.5, 1.0, '灰度化')
