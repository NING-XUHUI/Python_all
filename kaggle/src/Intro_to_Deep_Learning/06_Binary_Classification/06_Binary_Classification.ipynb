# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../../datasets/Intro_to_Deep_Learning/dl_course_dataset/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February':2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_cat = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='NA'),
    OneHotEncoder(handle_unknown='ignore'),
)

transformer_num = make_pipeline(
    SimpleImputer(strategy='constant'),
    StandardScaler(),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

# %%
input_shape = [X_train.shape[1]]

# %%
print(input_shape)
# Out:
# [63]

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping]
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title='Cross-entropy')
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title='Accuracy')
# Out:
# Epoch 1/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4847 - binary_accuracy: 0.7695 - val_loss: 0.4321 - val_binary_accuracy: 0.8027
# Epoch 2/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4241 - binary_accuracy: 0.7997 - val_loss: 0.3997 - val_binary_accuracy: 0.8153
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4108 - binary_accuracy: 0.8070 - val_loss: 0.3937 - val_binary_accuracy: 0.8181
# Epoch 4/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4032 - binary_accuracy: 0.8113 - val_loss: 0.3868 - val_binary_accuracy: 0.8216
# Epoch 5/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3981 - binary_accuracy: 0.8142 - val_loss: 0.3856 - val_binary_accuracy: 0.8237
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3927 - binary_accuracy: 0.8172 - val_loss: 0.3847 - val_binary_accuracy: 0.8237
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3892 - binary_accuracy: 0.8191 - val_loss: 0.3806 - val_binary_accuracy: 0.8267
# Epoch 8/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3850 - binary_accuracy: 0.8213 - val_loss: 0.3832 - val_binary_accuracy: 0.8226
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3832 - binary_accuracy: 0.8225 - val_loss: 0.3734 - val_binary_accuracy: 0.8266
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3807 - binary_accuracy: 0.8237 - val_loss: 0.3735 - val_binary_accuracy: 0.8301
# Epoch 11/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3766 - binary_accuracy: 0.8257 - val_loss: 0.3689 - val_binary_accuracy: 0.8303
# Epoch 12/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3744 - binary_accuracy: 0.8272 - val_loss: 0.3695 - val_binary_accuracy: 0.8303
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3731 - binary_accuracy: 0.8273 - val_loss: 0.3652 - val_binary_accuracy: 0.8345
# Epoch 14/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3707 - binary_accuracy: 0.8286 - val_loss: 0.3667 - val_binary_accuracy: 0.8301
# Epoch 15/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3688 - binary_accuracy: 0.8296 - val_loss: 0.3648 - val_binary_accuracy: 0.8314
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3668 - binary_accuracy: 0.8312 - val_loss: 0.3668 - val_binary_accuracy: 0.8312
# Epoch 17/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3655 - binary_accuracy: 0.8313 - val_loss: 0.3617 - val_binary_accuracy: 0.8340
# Epoch 18/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3619 - binary_accuracy: 0.8329 - val_loss: 0.3616 - val_binary_accuracy: 0.8328
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3606 - binary_accuracy: 0.8338 - val_loss: 0.3603 - val_binary_accuracy: 0.8328
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3600 - binary_accuracy: 0.8334 - val_loss: 0.3572 - val_binary_accuracy: 0.8358
# Epoch 21/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3577 - binary_accuracy: 0.8344 - val_loss: 0.3572 - val_binary_accuracy: 0.8338
# Epoch 22/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3584 - binary_accuracy: 0.8345 - val_loss: 0.3560 - val_binary_accuracy: 0.8356
# Epoch 23/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3561 - binary_accuracy: 0.8348 - val_loss: 0.3558 - val_binary_accuracy: 0.8359
# Epoch 24/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3544 - binary_accuracy: 0.8359 - val_loss: 0.3539 - val_binary_accuracy: 0.8371
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3528 - binary_accuracy: 0.8363 - val_loss: 0.3542 - val_binary_accuracy: 0.8370
# Epoch 26/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3529 - binary_accuracy: 0.8367 - val_loss: 0.3529 - val_binary_accuracy: 0.8377
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3517 - binary_accuracy: 0.8367 - val_loss: 0.3516 - val_binary_accuracy: 0.8397
# Epoch 28/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3502 - binary_accuracy: 0.8389 - val_loss: 0.3520 - val_binary_accuracy: 0.8381
# Epoch 29/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3498 - binary_accuracy: 0.8387 - val_loss: 0.3529 - val_binary_accuracy: 0.8392
# Epoch 30/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3489 - binary_accuracy: 0.8399 - val_loss: 0.3511 - val_binary_accuracy: 0.8379
# Epoch 31/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3472 - binary_accuracy: 0.8403 - val_loss: 0.3534 - val_binary_accuracy: 0.8369
# Epoch 32/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3471 - binary_accuracy: 0.8397 - val_loss: 0.3530 - val_binary_accuracy: 0.8388
# <AxesSubplot:title={'center':'Accuracy'}>
