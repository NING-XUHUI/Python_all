# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler

# %%
L_quzhou_FMW = pd.read_csv('./FMW/L-quzhou_FMW.csv')

# %%
column_L_quzhou_FMW = L_quzhou_FMW.columns

# %%
column_L_quzhou_FMW
# Out:
# Index(['X[s]', 'Trigno Avanti sensor 9: EMG 9 (IM)', 'X[s].1',
#        'Trigno Avanti sensor 9: Acc 9.X (IM)', 'X[s].2',
#        'Trigno Avanti sensor 9: Acc 9.Y (IM)', 'X[s].3',
#        'Trigno Avanti sensor 9: Acc 9.Z (IM)', 'X[s].4',
#        'Trigno Avanti sensor 9: Gyro 9.X (IM)', 'X[s].5',
#        'Trigno Avanti sensor 9: Gyro 9.Y (IM)', 'X[s].6',
#        'Trigno Avanti sensor 9: Gyro 9.Z (IM)', 'X[s].7',
#        'Trigno Avanti sensor 9: Mag 9.X (IM)', 'X[s].8',
#        'Trigno Avanti sensor 9: Mag 9.Y (IM)', 'X[s].9',
#        'Trigno Avanti sensor 9: Mag 9.Z (IM)', 'X[s].10',
#        'Trigno Avanti sensor 10: EMG 10 (IM)', 'X[s].11',
#        'Trigno Avanti sensor 10: Acc 10.X (IM)', 'X[s].12',
#        'Trigno Avanti sensor 10: Acc 10.Y (IM)', 'X[s].13',
#        'Trigno Avanti sensor 10: Acc 10.Z (IM)', 'X[s].14',
#        'Trigno Avanti sensor 10: Gyro 10.X (IM)', 'X[s].15',
#        'Trigno Avanti sensor 10: Gyro 10.Y (IM)', 'X[s].16',
# ...

# %%
L_shenzhou_FMW = pd.read_csv('./FMW/L-shenzhou_FMW.csv')
column_L_shenzhou_FMW = L_shenzhou_FMW.columns

# %%
column_L_shenzhou_FMW
# Out:
# Index(['X[s]', 'Trigno Avanti sensor 9: EMG 9 (IM)', 'X[s].1',
#        'Trigno Avanti sensor 9: Acc 9.X (IM)', 'X[s].2',
#        'Trigno Avanti sensor 9: Acc 9.Y (IM)', 'X[s].3',
#        'Trigno Avanti sensor 9: Acc 9.Z (IM)', 'X[s].4',
#        'Trigno Avanti sensor 9: Gyro 9.X (IM)', 'X[s].5',
#        'Trigno Avanti sensor 9: Gyro 9.Y (IM)', 'X[s].6',
#        'Trigno Avanti sensor 9: Gyro 9.Z (IM)', 'X[s].7',
#        'Trigno Avanti sensor 9: Mag 9.X (IM)', 'X[s].8',
#        'Trigno Avanti sensor 9: Mag 9.Y (IM)', 'X[s].9',
#        'Trigno Avanti sensor 9: Mag 9.Z (IM)', 'X[s].10',
#        'Trigno Avanti sensor 10: EMG 10 (IM)', 'X[s].11',
#        'Trigno Avanti sensor 10: Acc 10.X (IM)', 'X[s].12',
#        'Trigno Avanti sensor 10: Acc 10.Y (IM)', 'X[s].13',
#        'Trigno Avanti sensor 10: Acc 10.Z (IM)', 'X[s].14',
#        'Trigno Avanti sensor 10: Gyro 10.X (IM)', 'X[s].15',
#        'Trigno Avanti sensor 10: Gyro 10.Y (IM)', 'X[s].16',
# ...

# %%
L_wanqu_FMW = pd.read_csv('./FMW/L-wanqu_FMW.csv')
column_L_wanqu_FMW = L_wanqu_FMW.columns

# %%
column_L_wanqu_FMW
# Out:
# Index(['X[s]', 'Trigno Avanti sensor 3: EMG 3 (IM)', 'X[s].1',
#        'Trigno Avanti sensor 3: Acc 3.X (IM)', 'X[s].2',
#        'Trigno Avanti sensor 3: Acc 3.Y (IM)', 'X[s].3',
#        'Trigno Avanti sensor 3: Acc 3.Z (IM)', 'X[s].4',
#        'Trigno Avanti sensor 3: Gyro 3.X (IM)',
#        ...
#        'X[s].77', 'Trigno Avanti sensor 10: Mag 10.X (IM)', 'X[s].78',
#        'Trigno Avanti sensor 10: Mag 10.Y (IM)', 'X[s].79',
#        'Trigno Avanti sensor 10: Mag 10.Z (IM)', 'X[s].80',
#        'Trigno Goniometer sensor 16: Goni 16.A', 'X[s].81',
#        'Trigno Goniometer sensor 16: Goni 16.B'],
#       dtype='object', length=164)

# %%
L_wanshen_FMW = pd.read_csv('./FMW/L-wanshen_FMW.csv')
column_L_wanshen_FMW = L_wanshen_FMW.columns

# %%
for i in range(len(column_L_wanshen_FMW)):
    print(str(i) + ' ' + column_L_wanshen_FMW[i])
# Out:
# 0 X[s]
# 1 Trigno Avanti sensor 3: EMG 3 (IM)
# 2 X[s].1
# 3 Trigno Avanti sensor 3: Acc 3.X (IM)
# 4 X[s].2
# 5 Trigno Avanti sensor 3: Acc 3.Y (IM)
# 6 X[s].3
# 7 Trigno Avanti sensor 3: Acc 3.Z (IM)
# 8 X[s].4
# 9 Trigno Avanti sensor 3: Gyro 3.X (IM)
# 10 X[s].5
# 11 Trigno Avanti sensor 3: Gyro 3.Y (IM)
# 12 X[s].6
# 13 Trigno Avanti sensor 3: Gyro 3.Z (IM)
# 14 X[s].7
# 15 Trigno Avanti sensor 3: Mag 3.X (IM)
# 16 X[s].8
# 17 Trigno Avanti sensor 3: Mag 3.Y (IM)
# 18 X[s].9
# 19 Trigno Avanti sensor 3: Mag 3.Z (IM)
# 20 X[s].10
# 21 Trigno Avanti sensor 4: EMG 4 (IM)
# 22 X[s].11
# 23 Trigno Avanti sensor 4: Acc 4.X (IM)
# 24 X[s].12
# 25 Trigno Avanti sensor 4: Acc 4.Y (IM)
# 26 X[s].13
# 27 Trigno Avanti sensor 4: Acc 4.Z (IM)
# 28 X[s].14
# 29 Trigno Avanti sensor 4: Gyro 4.X (IM)
# 30 X[s].15
# 31 Trigno Avanti sensor 4: Gyro 4.Y (IM)
# 32 X[s].16
# 33 Trigno Avanti sensor 4: Gyro 4.Z (IM)
# 34 X[s].17
# 35 Trigno Avanti sensor 4: Mag 4.X (IM)
# 36 X[s].18
# ...

# %%
plt.figure(figsize=(20,8))
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[0]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[1]][1024:1536])
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[20]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[21]][1024:1536])
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[40]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[41]][1024:1536])
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[60]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[61]][1024:1536])
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[80]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[81]][1024:1536])
plt.plot(L_wanshen_FMW[column_L_wanshen_FMW[100]][1024:2048], L_wanshen_FMW[column_L_wanshen_FMW[101]][1024:2048])
